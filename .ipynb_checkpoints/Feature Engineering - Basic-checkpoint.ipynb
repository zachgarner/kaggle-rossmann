# %%
import pandas
from pandas import DataFrame
# %matplotlib inline
import seaborn
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn import cross_validation

import numpy
import math

# %%
train_all_df = DataFrame.from_csv("train.csv", index_col=['Store', 'Date'], parse_dates=['Date'])
train_all_df.reset_index(inplace=True)
train_all_df.head()
# Out:
# /opt/conda/lib/python3.4/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#    Store       Date  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1 2015-07-31          5   5263        555     1      1            0
# 1      2 2015-07-31          5   6064        625     1      1            0
# 2      3 2015-07-31          5   8314        821     1      1            0
# 3      4 2015-07-31          5  13995       1498     1      1            0
# 4      5 2015-07-31          5   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
test_df = DataFrame.from_csv("test.csv", index_col=['Store', 'Date'], parse_dates=['Date'])
test_df.reset_index(inplace=True)
test_df.head()
# Out:
#    Store       Date  Id  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday
# 0      1 2015-09-17   1          4     1      1            0              0
# 1      3 2015-09-17   2          4     1      1            0              0
# 2      7 2015-09-17   3          4     1      1            0              0
# 3      8 2015-09-17   4          4     1      1            0              0
# 4      9 2015-09-17   5          4     1      1            0              0

# %%
def featurize_basic(df):
    df = df.copy()
    def featurizeStateHoliday(x):
        if x == 'a':
            return 1
        elif x == 'b':
            return 2
        elif x == 'c':
            return 3
        else:
            return x
    df['StateHoliday'] = df['StateHoliday'].map(lambda x: featurizeStateHoliday(x))
    

    def featurizeDate(ts): 
        features = {}
        features['cal:dayOfMonth'] = ts.day
        features['cal:dayOfWeek'] = ts.dayofweek
        features['cal:dayofyear'] = ts.dayofyear
        features['cal:month'] = ts.month
        features['cal:year'] = ts.year
        features['cal:weekofyear'] =  ts.weekofyear
        features['cal:quarter'] = ts.quarter

        return features

    date_features_series = df['Date'].map(lambda x: featurizeDate(x))
    date_features = DataFrame.from_records(date_features_series.tolist(), index=df['Date'])

    del df['Date']
    
    df = pandas.concat([df, date_features.reset_index()], axis=1)

    
    return df

# %%
train_all_df = featurize_basic(train_all_df)

# Shuffle columnstrain_all_df.head()
columns = list(train_all_df.columns)
print (columns)
columns.remove("Sales")
columns.remove("Date")
columns = ["Sales"] + columns

train_all_df = train_all_df[columns]

train_all_df.head()
# Out:
# ['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 'cal:dayOfMonth', 'cal:dayOfWeek', 'cal:dayofyear', 'cal:month', 'cal:quarter', 'cal:weekofyear', 'cal:year', 'Date', 'cal:dayOfMonth', 'cal:dayOfWeek', 'cal:dayofyear', 'cal:month', 'cal:quarter', 'cal:weekofyear', 'cal:year']
#    Sales  Store  DayOfWeek  Customers  Open  Promo StateHoliday  \
# 0   5263      1          5        555     1      1            0
# 1   6064      2          5        625     1      1            0
# 2   8314      3          5        821     1      1            0
# 3  13995      4          5       1498     1      1            0
# 4   4822      5          5        559     1      1            0
#
#    SchoolHoliday  cal:dayOfMonth  cal:dayOfMonth    ...     cal:dayofyear  \
# 0              1              31              31    ...               212
# 1              1              31              31    ...               212
# 2              1              31              31    ...               212
# 3              1              31              31    ...               212
# 4              1              31              31    ...               212
#
#    cal:dayofyear  cal:month  cal:month  cal:quarter  cal:quarter  \
# 0            212          7          7            3            3
# 1            212          7          7            3            3
# 2            212          7          7            3            3
# 3            212          7          7            3            3
# 4            212          7          7            3            3
#
#    cal:weekofyear  cal:weekofyear  cal:year  cal:year
# 0              31              31      2015      2015
# 1              31              31      2015      2015
# 2              31              31      2015      2015
# 3              31              31      2015      2015
# 4              31              31      2015      2015
#
# [5 rows x 36 columns]

# %%
test_df = featurize_basic(test_df)
test_df.head()
# Out:
#    Store  Id  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday       Date  \
# 0      1   1          4     1      1            0              0 2015-09-17
# 1      3   2          4     1      1            0              0 2015-09-17
# 2      7   3          4     1      1            0              0 2015-09-17
# 3      8   4          4     1      1            0              0 2015-09-17
# 4      9   5          4     1      1            0              0 2015-09-17
#
#    cal:dayOfMonth  cal:dayOfWeek  cal:dayofyear  cal:month  cal:quarter  \
# 0              17              3            260          9            3
# 1              17              3            260          9            3
# 2              17              3            260          9            3
# 3              17              3            260          9            3
# 4              17              3            260          9            3
#
#    cal:weekofyear  cal:year
# 0              38      2015
# 1              38      2015
# 2              38      2015
# 3              38      2015
# 4              38      2015

# %%
train_all_df.to_csv("train_features_basic.csv", index=None)
test_df.to_csv("test_features_basic.csv", index=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-633525119ba8> in <module>()
# ----> 1 del train_all_df['Date']
#       2 del test_df['Date']
#       3
#       4 train_all_df.to_csv("train_features_basic.csv", index=None)
#       5 test_df.to_csv("test_features_basic.csv", index=None)
#
# /opt/conda/lib/python3.4/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    1330             # there was no match, this call should raise the appropriate
#    1331             # exception:
# -> 1332             self._data.delete(key)
#    1333
#    1334         try:
#
# /opt/conda/lib/python3.4/site-packages/pandas/core/internals.py in delete(self, item)
#    2907         Delete selected item (items if non-unique) in-place.
#    2908         """
# -> 2909         indexer = self.items.get_loc(item)
#    2910
#    2911         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# /opt/conda/lib/python3.4/site-packages/pandas/core/index.py in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3651)()
#
# pandas/index.pyx in pandas.index.IndexEngine._get_loc_duplicates (pandas/index.c:4042)()
#
# pandas/index.pyx in pandas.index.IndexEngine._maybe_get_bool_indexer (pandas/index.c:4393)()
#
# KeyError: 'Date'
